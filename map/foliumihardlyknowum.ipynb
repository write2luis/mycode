# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
# Define coordinates of where to start our map
# 
# hershey = [40.284, -76.649]
# disney = [28.385, -81.563]
# boulder = [40.015, -105.2705]
# kansascity = [39.099, -94.578]

start_location = [40.284, -76.649]

# Create the map
my_map = folium.Map(location = start_location,  # Latitude and Longitude of Map 
                    zoom_start = 13)            # Initial zoom level for the map (default is 10)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8be837823c846513bd7d8bc7fb0151ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8be837823c846513bd7d8bc7fb0151ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8be837823c846513bd7d8bc7fb0151ca = L.map(
#                 &quot;map_8be837823c846513bd7d8bc7fb0151ca&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6edd553ed87c08bacc23b355a54f9c9f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8be837823c846513bd7d8bc7fb0151ca);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Define the coordinates we want our markers to be at
hershey_hotel = [40.300, -76.659]     # famous hotel
hershey_park = [40.288, -76.654]   # family theme park
comics_and_paperback_plus = [40.179, -76.179]  # local comic shop


# Add markers to the map
# popup --> label for the Marker; click on the pins on the map!
folium.Marker(hershey_hotel, popup = 'Hershey Hotel').add_to(my_map)
folium.Marker(hershey_park, popup = 'Hershey Park').add_to(my_map)
folium.Marker(comics_and_paperback_plus, popup = 'Comics and Paperback Plus').add_to(my_map)

# change the icon on a marker (location of Hershey Factory)
# see more icons here: https://getbootstrap.com/docs/3.3/components/
folium.Marker([40.285, -76.650], popup = 'Hershey Factory', icon=folium.Icon(color="red", icon="info-sign")).add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8be837823c846513bd7d8bc7fb0151ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8be837823c846513bd7d8bc7fb0151ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8be837823c846513bd7d8bc7fb0151ca = L.map(
#                 &quot;map_8be837823c846513bd7d8bc7fb0151ca&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6edd553ed87c08bacc23b355a54f9c9f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8be837823c846513bd7d8bc7fb0151ca);
#
#
#             var marker_2faebef398c183eb320c095808b0d290 = L.marker(
#                 [40.3, -76.659],
#                 {}
#             ).addTo(map_8be837823c846513bd7d8bc7fb0151ca);
#
#
#         var popup_d8373bba82162392082b34143852fd50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29a400164bcd1c14a69ac09462fe8bd9 = $(`&lt;div id=&quot;html_29a400164bcd1c14a69ac09462fe8bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Hotel&lt;/div&gt;`)[0];
#                 popup_d8373bba82162392082b34143852fd50.setContent(html_29a400164bcd1c14a69ac09462fe8bd9);
#
#
#
#         marker_2faebef398c183eb320c095808b0d290.bindPopup(popup_d8373bba82162392082b34143852fd50)
#         ;
#
#
#
#
#             var marker_4d2da5259890c81f8f867cf15a0a6cc9 = L.marker(
#                 [40.288, -76.654],
#                 {}
#             ).addTo(map_8be837823c846513bd7d8bc7fb0151ca);
#
#
#         var popup_edb38807fa1ec6ed22e63754cd37431a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_645385a5658a5193e719e2ca8afac712 = $(`&lt;div id=&quot;html_645385a5658a5193e719e2ca8afac712&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Park&lt;/div&gt;`)[0];
#                 popup_edb38807fa1ec6ed22e63754cd37431a.setContent(html_645385a5658a5193e719e2ca8afac712);
#
#
#
#         marker_4d2da5259890c81f8f867cf15a0a6cc9.bindPopup(popup_edb38807fa1ec6ed22e63754cd37431a)
#         ;
#
#
#
#
#             var marker_14ceace7e65f6ee806bb6bc6b2e6fec4 = L.marker(
#                 [40.179, -76.179],
#                 {}
#             ).addTo(map_8be837823c846513bd7d8bc7fb0151ca);
#
#
#         var popup_ea5dc8b4c0afca29fda953ae31715917 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d19db6bddf4ac5347bfda2be4d8cf35f = $(`&lt;div id=&quot;html_d19db6bddf4ac5347bfda2be4d8cf35f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Comics and Paperback Plus&lt;/div&gt;`)[0];
#                 popup_ea5dc8b4c0afca29fda953ae31715917.setContent(html_d19db6bddf4ac5347bfda2be4d8cf35f);
#
#
#
#         marker_14ceace7e65f6ee806bb6bc6b2e6fec4.bindPopup(popup_ea5dc8b4c0afca29fda953ae31715917)
#         ;
#
#
#
#
#             var marker_2cfacedea9e94e132cc04b002ccf1dd1 = L.marker(
#                 [40.285, -76.65],
#                 {}
#             ).addTo(map_8be837823c846513bd7d8bc7fb0151ca);
#
#
#             var icon_874a7a832c5e48adbc660c5a22127280 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2cfacedea9e94e132cc04b002ccf1dd1.setIcon(icon_874a7a832c5e48adbc660c5a22127280);
#
#
#         var popup_7484735ece86ed655770d5fafca29f4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46f5f88541020b5a70d4c20b053c393a = $(`&lt;div id=&quot;html_46f5f88541020b5a70d4c20b053c393a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Factory&lt;/div&gt;`)[0];
#                 popup_7484735ece86ed655770d5fafca29f4e.setContent(html_46f5f88541020b5a70d4c20b053c393a);
#
#
#
#         marker_2cfacedea9e94e132cc04b002ccf1dd1.bindPopup(popup_7484735ece86ed655770d5fafca29f4e)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map.save("index.html")

# %%
# Using polygon markers with colors instead of default markers
polygon_map = folium.Map(location = start_location, zoom_start = 13)

# points of interest
hershey_hotel = [40.300, -76.659]     # famous hotel
hershey_park = [40.288, -76.654]   # family theme park
comics_and_paperback_plus = [40.179, -76.179]  # local comic shop


# Add markers to the map
folium.RegularPolygonMarker(hershey_hotel, popup = 'Hershey Hotel', fill_color = '#00ff40',
                            number_of_sides = 3, radius = 10).add_to(polygon_map)
folium.RegularPolygonMarker(hershey_park, popup = 'Hershey Park', fill_color = '#bf00ff',
                            number_of_sides = 5, radius = 10).add_to(polygon_map)
folium.RegularPolygonMarker(comics_and_paperback_plus, popup = 'Comics and Paperback Plus', fill_color = '#ff0000',
                           number_of_sides = 8, radius = 10).add_to(polygon_map)

#Display the map
polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a3d6d88442133353cf7005bd23f0898 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a3d6d88442133353cf7005bd23f0898&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7a3d6d88442133353cf7005bd23f0898 = L.map(
#                 &quot;map_7a3d6d88442133353cf7005bd23f0898&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44ae430ef1d77308bdebab857fa841ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a3d6d88442133353cf7005bd23f0898);
#
#
#             var regular_polygon_marker_07e649fd48173dd05817803b8fa35dce = new L.RegularPolygonMarker(
#                 [40.3, -76.659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00ff40&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a3d6d88442133353cf7005bd23f0898);
#
#
#         var popup_e9dde9ecd267c58523735b296868671e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c2fb4235df5ef03090e835cb2a5d607 = $(`&lt;div id=&quot;html_7c2fb4235df5ef03090e835cb2a5d607&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Hotel&lt;/div&gt;`)[0];
#                 popup_e9dde9ecd267c58523735b296868671e.setContent(html_7c2fb4235df5ef03090e835cb2a5d607);
#
#
#
#         regular_polygon_marker_07e649fd48173dd05817803b8fa35dce.bindPopup(popup_e9dde9ecd267c58523735b296868671e)
#         ;
#
#
#
#
#             var regular_polygon_marker_b06b005d66e1b8205e47727577e6683b = new L.RegularPolygonMarker(
#                 [40.288, -76.654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#bf00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 5, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a3d6d88442133353cf7005bd23f0898);
#
#
#         var popup_72eafe8d5d59ed09ce9a9594b7c28eed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a65b340a9e85b72998f08536dbb7e37 = $(`&lt;div id=&quot;html_9a65b340a9e85b72998f08536dbb7e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Park&lt;/div&gt;`)[0];
#                 popup_72eafe8d5d59ed09ce9a9594b7c28eed.setContent(html_9a65b340a9e85b72998f08536dbb7e37);
#
#
#
#         regular_polygon_marker_b06b005d66e1b8205e47727577e6683b.bindPopup(popup_72eafe8d5d59ed09ce9a9594b7c28eed)
#         ;
#
#
#
#
#             var regular_polygon_marker_e31be3e538d14a1f5f3f581e4b5124e1 = new L.RegularPolygonMarker(
#                 [40.179, -76.179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 8, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a3d6d88442133353cf7005bd23f0898);
#
#
#         var popup_a191488771c37bf2646f7499c415f86d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5133bb8c7c7213770a7417b983298c1c = $(`&lt;div id=&quot;html_5133bb8c7c7213770a7417b983298c1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Comics and Paperback Plus&lt;/div&gt;`)[0];
#                 popup_a191488771c37bf2646f7499c415f86d.setContent(html_5133bb8c7c7213770a7417b983298c1c);
#
#
#
#         regular_polygon_marker_e31be3e538d14a1f5f3f581e4b5124e1.bindPopup(popup_a191488771c37bf2646f7499c415f86d)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;

# %%
#Adding a tileset to our map
map_with_tiles = folium.Map(location = start_location, tiles = 'Stamen Toner')
map_with_tiles
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c206d4ccbcc5607363762cd67e842e1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c206d4ccbcc5607363762cd67e842e1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c206d4ccbcc5607363762cd67e842e1d = L.map(
#                 &quot;map_c206d4ccbcc5607363762cd67e842e1d&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_604d60e54d4de4435487b0a78ed4760c = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c206d4ccbcc5607363762cd67e842e1d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
